# %% [markdown]
# <a href="https://colab.research.google.com/github/Ersourabhkumar/python/blob/main/clutter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
if __name__ == '__main__':
    print("Hello, world.")
# Out:
# Hello, world.

# %%
import os
os.rename("xyz.txt","123.txt")

files=os.listdir()
i=1
for file in files:
  if file.endswith(".txt"):

      print(files)
      os.rename(file,str(i)+".txt")
      i+=1
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1073/477900249.py in <cell line: 0>()
#       1 import os
# ----> 2 os.rename("xyz.txt","123.txt")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'xyz.txt' -> '123.txt'
