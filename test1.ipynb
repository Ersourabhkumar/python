# %% [markdown]
# <a href="https://colab.research.google.com/github/Ersourabhkumar/python/blob/main/test1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n=12345
c=0
while n>0:
  c+=1
  n=n//10


print(c)
# Out:
# 5

# %%
n=int(input(""))
sum=0
for i in  range(n+1):
  sum+=i
print(sum)
# Out:
# 7\
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_14577/1168521975.py in <cell line: 0>()
# ----> 1 n=int(input(""))
#       2 sum=0
#       3 for i in  range(n+1):
#       4   sum+=i
#       5 print(sum)
#
# ValueError: invalid literal for int() with base 10: '7\\'

# %%
n=121
temp=n
t=0
while n>0:
  s=n%10
  t=t*10+s
  n//=10
if temp==t:
  print("palindrome")
else:
  print("not palindrome")
# Out:
# palindrome

# %%
n="121"
for i in range(len(n)):
  for j in range(i+1,len(n)/2+1):
    if n[i]!=n[j]:
      print("not palindrome")
    else:
      print("palindrome")

# %%
arr=[10,20,30,40,50]
for i in range(len(arr)):
  if i%2==0:
    print(list(map(arr[i]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_14577/2536940330.py in <cell line: 0>()
#       2 for i in range(len(arr)):
#       3   if i%2==0:
# ----> 4     print(list(arr[i]))
#       5
#
# TypeError: 'int' object is not iterable

# %%
n=3
for i in range(1,n+1):
  for j in range(2):
    print("*"*(i*2))
# Out:
# **
# **
# ****
# ****
# ******
# ******

# %%
n=4554
temp=n
t=0
while n>0:
  s=n%10
  t=t*10+s
  n//=10
if t==temp:
  print(True)
# Out:
# True

# %%
arr=list(map(int,input(" ").split()))
for i in range(0,len(arr),2):
  print(arr[i],end=" ")
# Out:
#  46 64 4 45 346 3 6 53
# 46
# 4
# 346
# 6
