# %% [markdown]
# <a href="https://colab.research.google.com/github/Ersourabhkumar/python/blob/main/pattern_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
*****
*   *
*   *
*   *
*****
"""
n=5
for i in range(1,n+1):
  if i==1 or i==n:
    print("*"*n)
  else:
    print("*"+" "*(n-2)+"*")
# Out:
# *****
# *   *
# *   *
# *   *
# *****

# %%
n = 5

for i in range(n):
    for j in range(n):

        if i == 0 or i == n-1 or j == 0 or j == n-1:
            print("a", end="")
    print()
# Out:
# aaaaa
# aa
# aa
# aa
# aaaaa
