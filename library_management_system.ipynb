# %% [markdown]
# <a href="https://colab.research.google.com/github/Ersourabhkumar/python/blob/main/library_management_system.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Employee:
    def __init__(self,salary):
      self.__salary=salary
a=Employee(50000)
# print(a.__salary)  can't access directly
print(a._Employee__salary)  #can access directly
# Out:
# 50000

# %%
# name mangling
print(a._Employee__salary)
# Out:
# 50000

# %%
print(a.__dir__())
# Out:
# ['_Employee__salary', '__module__', '__init__', '__dict__', '__weakref__', '__doc__', '__new__', '__repr__', '__hash__', '__str__', '__getattribute__', '__setattr__', '__delattr__', '__lt__', '__le__', '__eq__', '__ne__', '__gt__', '__ge__', '__reduce_ex__', '__reduce__', '__getstate__', '__subclasshook__', '__init_subclass__', '__format__', '__sizeof__', '__dir__', '__class__']

# %%
class student:
  def __init__(self):
    self._name="sourabh"

a=student()
print(a._name)
#protective
# Out:
# sourabh

# %%
# Library management
class library:
    def __init__(self):
     self.books=[]
     self.no_books=0
    def add_books(self,book):
      self.books.append(book)
      self.no_books=len(self.books)
    def info(self):
      print(f"the books has {self.no_books}. the books are {self.books}")

l1=library()
l1.add_books("python")
l1.add_books("java")
l1.add_books("c++")
l1.info()
# Out:
# the books has 3. the books are ['python', 'java', 'c++']

# %%
#proper code advance
class Library:
    def __init__(self):
        self.books = []

    def add_book(self, book):
        self.books.append(book)
        print(f"{book} added successfully!")

    def remove_book(self, book):
        if book in self.books:
            self.books.remove(book)
            print(f"{book} removed successfully!")
        else:
            print("Book not found!")

    def show_books(self):
        if len(self.books) == 0:
            print("No books available.")
        else:
            print("\nAvailable Books:")
            for i, book in enumerate(self.books, start=1):
                print(f"{i}. {book}")


# Object Creation
library = Library()

while True:
    print("\n--- Library Management System ---")
    print("1. Add Book")
    print("2. Remove Book")
    print("3. Show Books")
    print("4. Exit")

    choice = input("Enter your choice: ")

    if choice == "1":
        book = input("Enter book name: ")
        library.add_book(book)

    elif choice == "2":
        book = input("Enter book name to remove: ")
        library.remove_book(book)

    elif choice == "3":
        library.show_books()

    elif choice == "4":
        print("Thank You!")
        break

    else:
        print("Invalid Choice!")
# Out:
# --- Library Management System ---
# 1. Add Book
# 2. Remove Book
# 3. Show Books
# 4. Exit
# Enter your choice: 4
# Thank You!
